# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# https://www.statsmodels.org/stable/index.html
import statsmodels.api as sm

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from functools import partial

# %%
from dotenv import load_dotenv

from pathlib import Path

env_path = Path("../../.env-live")

if env_path.exists():
    print('envs Loaded')
    load_dotenv(dotenv_path=env_path)
from jrjModelRegistry.jrjModelRegistry import registerAJrjModel
# Out:
# envs Loaded
# Pinged your deployment. You successfully connected to MongoDB!

# %%
def generalRegressionPredictor(self, transformedData):
    return self.predict(transformedData)

# %%
sallaryMisDf = pd.read_excel("https://www.dropbox.com/scl/fi/zt2vtwhpz8ndblsxqdqx1/Salary_MIS.xlsx?rlkey=2uk6m7m9w90isv6zsynhhhpyv&st=gxumjns5&dl=1")

# %%
sallaryMisDf
# Out:
#      Salary   GPA  MIS  Statistics
# 0        72  3.53    1           0
# 1        66  2.86    1           0
# 2        72  3.69    0           0
# 3        63  3.24    0           0
# 4        65  3.21    0           0
# ..      ...   ...  ...         ...
# 115      66  3.27    0           0
# 116      63  2.86    1           0
# 117      78  3.04    1           1
# 118      64  2.99    0           0
# 119      66  3.65    0           0
#
# [120 rows x 4 columns]

# %%
sallaryMisDf.shape
# Out:
# (120, 4)

# %%
sallaryMisDf.describe()
# Out:
#            Salary         GPA         MIS  Statistics
# count  120.000000  120.000000  120.000000  120.000000
# mean    69.875000    3.242750    0.316667    0.341667
# std      6.594577    0.493834    0.467127    0.476257
# min     53.000000    2.410000    0.000000    0.000000
# 25%     65.750000    2.805000    0.000000    0.000000
# 50%     70.000000    3.280000    0.000000    0.000000
# 75%     73.250000    3.692500    1.000000    1.000000
# max     88.000000    3.980000    1.000000    1.000000

# %%
sallaryMisDf.shape
# Out:
# (120, 4)

# %%
def salaryRegModel1Transformer(dataForTransfer = None):
    import pandas as pd
    import statsmodels.api as sm
    if isinstance(dataForTransfer, pd.DataFrame):
        df = dataForTransfer.copy()
    else:
        df = pd.DataFrame(dataForTransfer)
    dfTransformer = sm.add_constant(df[['GPA', 'MIS', 'Statistics']],has_constant='add')
    return dfTransformer

# %%
sm.add_constant(sallaryMisDf[["GPA", "MIS", "Statistics"]])
# Out:
#      const   GPA  MIS  Statistics
# 0      1.0  3.53    1           0
# 1      1.0  2.86    1           0
# 2      1.0  3.69    0           0
# 3      1.0  3.24    0           0
# 4      1.0  3.21    0           0
# ..     ...   ...  ...         ...
# 115    1.0  3.27    0           0
# 116    1.0  2.86    1           0
# 117    1.0  3.04    1           1
# 118    1.0  2.99    0           0
# 119    1.0  3.65    0           0
#
# [120 rows x 4 columns]

# %%
salaryRegModel1Transformer(sallaryMisDf)
# Out:
#      const   GPA  MIS  Statistics
# 0      1.0  3.53    1           0
# 1      1.0  2.86    1           0
# 2      1.0  3.69    0           0
# 3      1.0  3.24    0           0
# 4      1.0  3.21    0           0
# ..     ...   ...  ...         ...
# 115    1.0  3.27    0           0
# 116    1.0  2.86    1           0
# 117    1.0  3.04    1           1
# 118    1.0  2.99    0           0
# 119    1.0  3.65    0           0
#
# [120 rows x 4 columns]

# %%
# salaryRegModel1 = sm.OLS(
#   sallaryMisDf["Salary"],
#   sm.add_constant(sallaryMisDf[["GPA", "MIS", "Statistics"]])
# )

# %%
salaryRegModel1 = sm.OLS(
  sallaryMisDf["Salary"],
  salaryRegModel1Transformer(sallaryMisDf)
)

# %%
    salaryRegModel1Fit = salaryRegModel1.fit()

# %%
print(salaryRegModel1Fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.795
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     150.3
# Date:                Fri, 11 Jul 2025   Prob (F-statistic):           8.35e-40
# Time:                        01:14:02   Log-Likelihood:                -300.92
# No. Observations:                 120   AIC:                             609.8
# Df Residuals:                     116   BIC:                             621.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         44.0072      1.860     23.662      0.000      40.324      47.691
# GPA            6.6227      0.569     11.649      0.000       5.497       7.749
# MIS            6.6071      0.595     11.098      0.000       5.428       7.786
# Statistics     6.7309      0.591     11.391      0.000       5.561       7.901
# ==============================================================================
# Omnibus:                        1.144   Durbin-Watson:                   2.164
# Prob(Omnibus):                  0.564   Jarque-Bera (JB):                0.758
# Skew:                          -0.172   Prob(JB):                        0.685
# Kurtosis:                       3.182   Cond. No.                         24.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sallaryMisDf
# Out:
#      Salary   GPA  MIS  Statistics
# 0        72  3.53    1           0
# 1        66  2.86    1           0
# 2        72  3.69    0           0
# 3        63  3.24    0           0
# 4        65  3.21    0           0
# ..      ...   ...  ...         ...
# 115      66  3.27    0           0
# 116      63  2.86    1           0
# 117      78  3.04    1           1
# 118      64  2.99    0           0
# 119      66  3.65    0           0
#
# [120 rows x 4 columns]

# %%
salaryRegModel1SampleData = {
    "GPA": [3.53],
    "MIS": [1],
    "Statistics": [0]
}

# %%
salaryRegModel1Fit.transformer = salaryRegModel1Transformer

# %%
test1 = salaryRegModel1Fit.transformer(salaryRegModel1SampleData)
test1
# salaryRegModel1Fit.mainPredictor(test1)
# Out:
#    const   GPA  MIS  Statistics
# 0    1.0  3.53    1           0

# %%
# def generalRegressionPredictor(self, transformedData):
#     return self.predict(transformedData)

# %%
salaryRegModel1Fit.mainPredictor = partial(generalRegressionPredictor, salaryRegModel1Fit)

# %%
salaryRegModel1Fit.mainPredictor(test1)
# Out:
# 0    73.992468
# dtype: float64

# %%
salaryRegModel1FitMetadata = {
    "modelName":f"silin_huang__salaryRegModel1Fit",
    "version":"1.0.1",
    "params": salaryRegModel1Fit.params.to_dict(),
    "score": float(salaryRegModel1Fit.rsquared),
    "modelLibraray": 'sm.OLS',
    "libraryMetadata": {
        "pvalues": salaryRegModel1Fit.pvalues.to_dict(),
        "r_squared": float(salaryRegModel1Fit.rsquared),
        "adj_r_squared": float(salaryRegModel1Fit.rsquared_adj)
    },

    "sampleData": {
        "dataForTransfer": salaryRegModel1SampleData
    }
}
salaryRegModel1FitMetadata
# Out:
# {'modelName': 'silin_huang__salaryRegModel1Fit',
#  'version': '1.0.1',
#  'params': {'const': 44.00724634057483,
#   'GPA': 6.622706150356178,
#   'MIS': 6.607068893822078,
#   'Statistics': 6.730931143358017},
#  'score': 0.7953924097617404,
#  'modelLibraray': 'sm.OLS',
#  'libraryMetadata': {'pvalues': {'const': 3.2704010980898553e-46,
#    'GPA': 3.077793077405891e-21,
#    'MIS': 6.058766938187725e-20,
#    'Statistics': 1.2379781357348497e-20},
#   'r_squared': 0.7953924097617404,
#   'adj_r_squared': 0.7901008341521303},
#  'sampleData': {'dataForTransfer': {'GPA': [3.53],
#    'MIS': [1],
#    'Statistics': [0]}}}

# %%
registerAJrjModel(salaryRegModel1Fit, salaryRegModel1FitMetadata)
# Out:
# ✅ Uploaded encrypted ZIP to s3://273-g5/silin_huang__salaryRegModel1Fit__1.0.1.pkl.zip
# {'_id': '686ff500345d1a0ee0583e16',
#  'modelName': 'silin_huang__salaryRegModel1Fit',
#  'version': '1.0.1',
#  'params': {'const': 44.00724634057483,
#   'GPA': 6.622706150356178,
#   'MIS': 6.607068893822078,
#   'Statistics': 6.730931143358017},
#  'score': 0.7953924097617404,
#  'modelLibraray': 'sm.OLS',
#  'libraryMetadata': {'pvalues': {'const': 3.2704010980898553e-46,
#    'GPA': 3.077793077405891e-21,
#    'MIS': 6.058766938187725e-20,
#    'Statistics': 1.2379781357348497e-20},
#   'r_squared': 0.7953924097617404,
#   'adj_r_squared': 0.7901008341521303},
#  'sampleData': {'dataForTransfer': {'GPA': [3.53],
#    'MIS': [1],
#    'Statistics': [0]}},
#  'modelType': 'model',
#  'keepLastOnly': False,
#  'modelSizeBytes': 20951,
#  'zippedModelSizeBytes': 8120,
#  's3Url': '273-g5/silin_huang__salaryRegModel1Fit__1.0.1.pkl.zip',
#  'createdAt': '2025-07-10T17:14:40.647Z',
#  'updatedAt': '2025-07-10T17:14:40.647Z'}

# %%
sallaryMisDf
# Out:
#      Salary   GPA  MIS  Statistics
# 0        72  3.53    1           0
# 1        66  2.86    1           0
# 2        72  3.69    0           0
# 3        63  3.24    0           0
# 4        65  3.21    0           0
# ..      ...   ...  ...         ...
# 115      66  3.27    0           0
# 116      63  2.86    1           0
# 117      78  3.04    1           1
# 118      64  2.99    0           0
# 119      66  3.65    0           0
#
# [120 rows x 4 columns]

# %%
# sallaryMisDf["misXStatistics"] = sallaryMisDf["MIS"] * sallaryMisDf["Statistics"]
sallaryMisDf['misXStatistics'] = sallaryMisDf.apply(lambda row: row['MIS'] * row['Statistics'], axis=1)

sallaryMisDf
# Out:
#      Salary   GPA  MIS  Statistics  misXStatistics
# 0        72  3.53    1           0             0.0
# 1        66  2.86    1           0             0.0
# 2        72  3.69    0           0             0.0
# 3        63  3.24    0           0             0.0
# 4        65  3.21    0           0             0.0
# ..      ...   ...  ...         ...             ...
# 115      66  3.27    0           0             0.0
# 116      63  2.86    1           0             0.0
# 117      78  3.04    1           1             1.0
# 118      64  2.99    0           0             0.0
# 119      66  3.65    0           0             0.0
#
# [120 rows x 5 columns]

# %%
def salaryRegModel2Transformer(dataForTransfer = None):
    import pandas as pd
    import statsmodels.api as sm
    if isinstance(dataForTransfer, pd.DataFrame):
        df = dataForTransfer.copy()
    else:
        df = pd.DataFrame(dataForTransfer)
    df['misXStatistics'] = df.apply(lambda row: row['MIS'] * row['Statistics'], axis=1)
    dfTransformer = sm.add_constant(df[['GPA', 'MIS', 'Statistics', 'misXStatistics']],has_constant='add')
    return dfTransformer

# %%
salaryRegModel2Transformer(sallaryMisDf)
# Out:
#      const   GPA  MIS  Statistics  misXStatistics
# 0      1.0  3.53    1           0             0.0
# 1      1.0  2.86    1           0             0.0
# 2      1.0  3.69    0           0             0.0
# 3      1.0  3.24    0           0             0.0
# 4      1.0  3.21    0           0             0.0
# ..     ...   ...  ...         ...             ...
# 115    1.0  3.27    0           0             0.0
# 116    1.0  2.86    1           0             0.0
# 117    1.0  3.04    1           1             1.0
# 118    1.0  2.99    0           0             0.0
# 119    1.0  3.65    0           0             0.0
#
# [120 rows x 5 columns]

# %%
salaryRegModel2 = sm.OLS(
  sallaryMisDf["Salary"],
  salaryRegModel2Transformer(sallaryMisDf)
)

# %%
salaryRegModel2Fit = salaryRegModel2.fit()

# %%
print(salaryRegModel2Fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     122.2
# Date:                Fri, 11 Jul 2025   Prob (F-statistic):           1.87e-40
# Time:                        01:14:59   Log-Likelihood:                -296.63
# No. Observations:                 120   AIC:                             603.3
# Df Residuals:                     115   BIC:                             617.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             44.0993      1.803     24.464      0.000      40.529      47.670
# GPA                6.7109      0.552     12.162      0.000       5.618       7.804
# MIS                5.3250      0.725      7.343      0.000       3.889       6.761
# Statistics         5.5350      0.704      7.861      0.000       4.140       6.930
# misXStatistics     3.4915      1.196      2.918      0.004       1.122       5.861
# ==============================================================================
# Omnibus:                        0.396   Durbin-Watson:                   2.073
# Prob(Omnibus):                  0.820   Jarque-Bera (JB):                0.109
# Skew:                          -0.013   Prob(JB):                        0.947
# Kurtosis:                       3.146   Cond. No.                         24.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
salaryRegModel2Fit.transformer = salaryRegModel2Transformer

# %%
salaryRegModel2Fit.mainPredictor = partial(generalRegressionPredictor, salaryRegModel2Fit)

# %%
test2 = salaryRegModel2Fit.transformer(salaryRegModel1SampleData)
test2
# Out:
#    const   GPA  MIS  Statistics  misXStatistics
# 0    1.0  3.53    1           0             0.0

# %%
salaryRegModel2Fit.mainPredictor(test2)
# Out:
# 0    73.113927
# dtype: float64

# %%
salaryRegModel2FitMetadata = {
    "modelName":f"silin_huang__salaryRegModel2Fit",
    "version":"1.0.1",
    "params": salaryRegModel2Fit.params.to_dict(),
    "score": float(salaryRegModel2Fit.rsquared),
    "modelLibraray": 'sm.OLS',
    "libraryMetadata": {
        "pvalues": salaryRegModel2Fit.pvalues.to_dict(),
        "r_squared": float(salaryRegModel2Fit.rsquared),
        "adj_r_squared": float(salaryRegModel2Fit.rsquared_adj)
    },

    "sampleData": {
        "dataForTransfer": salaryRegModel1SampleData
    }
}
salaryRegModel2FitMetadata
# Out:
# {'modelName': 'silin_huang__salaryRegModel2Fit',
#  'version': '1.0.1',
#  'params': {'const': 44.099326871515935,
#   'GPA': 6.710928968502127,
#   'MIS': 5.325020933077331,
#   'Statistics': 5.5349839504436105,
#   'misXStatistics': 3.4914565653155343},
#  'score': 0.8095004820146133,
#  'modelLibraray': 'sm.OLS',
#  'libraryMetadata': {'pvalues': {'const': 2.1308984053352826e-47,
#    'GPA': 2.206820882598635e-22,
#    'MIS': 3.2245297182829286e-11,
#    'Statistics': 2.259035391650431e-12,
#    'misXStatistics': 0.004233931884691076},
#   'r_squared': 0.8095004820146133,
#   'adj_r_squared': 0.8028744118238172},
#  'sampleData': {'dataForTransfer': {'GPA': [3.53],
#    'MIS': [1],
#    'Statistics': [0]}}}

# %%
registerAJrjModel(salaryRegModel2Fit, salaryRegModel2FitMetadata)
# Out:
# ✅ Uploaded encrypted ZIP to s3://273-g5/silin_huang__salaryRegModel2Fit__1.0.1.pkl.zip
# {'_id': '686ff52d345d1a0ee0583e17',
#  'modelName': 'silin_huang__salaryRegModel2Fit',
#  'version': '1.0.1',
#  'params': {'const': 44.099326871515935,
#   'GPA': 6.710928968502127,
#   'MIS': 5.325020933077331,
#   'Statistics': 5.5349839504436105,
#   'misXStatistics': 3.4914565653155343},
#  'score': 0.8095004820146133,
#  'modelLibraray': 'sm.OLS',
#  'libraryMetadata': {'pvalues': {'const': 2.1308984053352826e-47,
#    'GPA': 2.206820882598635e-22,
#    'MIS': 3.2245297182829286e-11,
#    'Statistics': 2.259035391650431e-12,
#    'misXStatistics': 0.004233931884691076},
#   'r_squared': 0.8095004820146133,
#   'adj_r_squared': 0.8028744118238172},
#  'sampleData': {'dataForTransfer': {'GPA': [3.53],
#    'MIS': [1],
#    'Statistics': [0]}},
#  'modelType': 'model',
#  'keepLastOnly': False,
#  'modelSizeBytes': 24286,
#  'zippedModelSizeBytes': 9279,
#  's3Url': '273-g5/silin_huang__salaryRegModel2Fit__1.0.1.pkl.zip',
#  'createdAt': '2025-07-10T17:15:25.092Z',
#  'updatedAt': '2025-07-10T17:15:25.092Z'}

# %%
sallaryMisDf['misXGpa'] = sallaryMisDf.apply(lambda row: row['MIS'] * row['GPA'], axis=1)

sallaryMisDf
# Out:
#      Salary   GPA  MIS  Statistics  misXStatistics  misXGpa
# 0        72  3.53    1           0             0.0     3.53
# 1        66  2.86    1           0             0.0     2.86
# 2        72  3.69    0           0             0.0     0.00
# 3        63  3.24    0           0             0.0     0.00
# 4        65  3.21    0           0             0.0     0.00
# ..      ...   ...  ...         ...             ...      ...
# 115      66  3.27    0           0             0.0     0.00
# 116      63  2.86    1           0             0.0     2.86
# 117      78  3.04    1           1             1.0     3.04
# 118      64  2.99    0           0             0.0     0.00
# 119      66  3.65    0           0             0.0     0.00
#
# [120 rows x 6 columns]

# %%
def salaryRegModel3Transformer(dataForTransfer = None):
    import pandas as pd
    import statsmodels.api as sm
    if isinstance(dataForTransfer, pd.DataFrame):
        df = dataForTransfer.copy()
    else:
        df = pd.DataFrame(dataForTransfer)
    df['misXGpa'] = df.apply(lambda row: row['MIS'] * row['GPA'], axis=1)
    dfTransformer = sm.add_constant(df[['GPA', 'MIS', 'Statistics', 'misXGpa']],has_constant='add')
    return dfTransformer

# %%
salaryRegModel3Transformer(sallaryMisDf)
# Out:
#      const   GPA  MIS  Statistics  misXGpa
# 0      1.0  3.53    1           0     3.53
# 1      1.0  2.86    1           0     2.86
# 2      1.0  3.69    0           0     0.00
# 3      1.0  3.24    0           0     0.00
# 4      1.0  3.21    0           0     0.00
# ..     ...   ...  ...         ...      ...
# 115    1.0  3.27    0           0     0.00
# 116    1.0  2.86    1           0     2.86
# 117    1.0  3.04    1           1     3.04
# 118    1.0  2.99    0           0     0.00
# 119    1.0  3.65    0           0     0.00
#
# [120 rows x 5 columns]

# %%
salaryRegModel3 = sm.OLS(
  sallaryMisDf["Salary"],
  salaryRegModel3Transformer(sallaryMisDf)
)

# %%
salaryRegModel3Fit = salaryRegModel3.fit()

# %%
print(salaryRegModel3Fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.795
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     111.8
# Date:                Fri, 11 Jul 2025   Prob (F-statistic):           1.11e-38
# Time:                        01:15:39   Log-Likelihood:                -300.91
# No. Observations:                 120   AIC:                             611.8
# Df Residuals:                     115   BIC:                             625.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         44.1653      2.307     19.142      0.000      39.595      48.736
# GPA            6.5737      0.709      9.278      0.000       5.170       7.977
# MIS            6.1605      3.873      1.591      0.114      -1.511      13.832
# Statistics     6.7350      0.594     11.330      0.000       5.558       7.912
# misXGpa        0.1381      1.184      0.117      0.907      -2.206       2.483
# ==============================================================================
# Omnibus:                        1.114   Durbin-Watson:                   2.167
# Prob(Omnibus):                  0.573   Jarque-Bera (JB):                0.727
# Skew:                          -0.167   Prob(JB):                        0.695
# Kurtosis:                       3.185   Cond. No.                         57.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
salaryRegModel3Fit.transformer = salaryRegModel3Transformer
salaryRegModel3Fit.mainPredictor = partial(generalRegressionPredictor, salaryRegModel3Fit)
registerAJrjModel(
    salaryRegModel3Fit,
    {
        "modelName":f"silin_huang__salaryRegModel3Fit",
        "version":"1.0.1",
        "params": salaryRegModel3Fit.params.to_dict(),
        "score": float(salaryRegModel3Fit.rsquared),
        "modelLibraray": 'sm.OLS',
        "libraryMetadata": {
            "pvalues": salaryRegModel3Fit.pvalues.to_dict(),
            "r_squared": float(salaryRegModel3Fit.rsquared),
            "adj_r_squared": float(salaryRegModel3Fit.rsquared_adj)
        },
    
        "sampleData": {
            "dataForTransfer": salaryRegModel1SampleData
        }
    }
)
# Out:
# ✅ Uploaded encrypted ZIP to s3://273-g5/silin_huang__salaryRegModel3Fit__1.0.1.pkl.zip
# {'_id': '686ff542345d1a0ee0583e18',
#  'modelName': 'silin_huang__salaryRegModel3Fit',
#  'version': '1.0.1',
#  'params': {'const': 44.1653208260671,
#   'GPA': 6.573741195731529,
#   'MIS': 6.160519814179626,
#   'Statistics': 6.734976129139474,
#   'misXGpa': 0.13813033815964104},
#  'score': 0.7954166374792891,
#  'modelLibraray': 'sm.OLS',
#  'libraryMetadata': {'pvalues': {'const': 1.492698753369242e-37,
#    'GPA': 1.2510679075808168e-15,
#    'MIS': 0.11442853694090012,
#    'Statistics': 1.9287999192095155e-20,
#    'misXGpa': 0.9073015272093081},
#   'r_squared': 0.7954166374792891,
#   'adj_r_squared': 0.7883006944350905},
#  'sampleData': {'dataForTransfer': {'GPA': [3.53],
#    'MIS': [1],
#    'Statistics': [0]}},
#  'modelType': 'model',
#  'keepLastOnly': False,
#  'modelSizeBytes': 24275,
#  'zippedModelSizeBytes': 9335,
#  's3Url': '273-g5/silin_huang__salaryRegModel3Fit__1.0.1.pkl.zip',
#  'createdAt': '2025-07-10T17:15:46.613Z',
#  'updatedAt': '2025-07-10T17:15:46.613Z'}

# %%
sallaryMisDf['statisticsXGpa'] = sallaryMisDf.apply(lambda row: row['Statistics'] * row['GPA'], axis=1)

sallaryMisDf
# Out:
#      Salary   GPA  MIS  Statistics  misXStatistics  misXGpa  statisticsXGpa
# 0        72  3.53    1           0             0.0     3.53            0.00
# 1        66  2.86    1           0             0.0     2.86            0.00
# 2        72  3.69    0           0             0.0     0.00            0.00
# 3        63  3.24    0           0             0.0     0.00            0.00
# 4        65  3.21    0           0             0.0     0.00            0.00
# ..      ...   ...  ...         ...             ...      ...             ...
# 115      66  3.27    0           0             0.0     0.00            0.00
# 116      63  2.86    1           0             0.0     2.86            0.00
# 117      78  3.04    1           1             1.0     3.04            3.04
# 118      64  2.99    0           0             0.0     0.00            0.00
# 119      66  3.65    0           0             0.0     0.00            0.00
#
# [120 rows x 7 columns]

# %%
def salaryRegModel4Transformer(dataForTransfer = None):
    import pandas as pd
    import statsmodels.api as sm
    if isinstance(dataForTransfer, pd.DataFrame):
        df = dataForTransfer.copy()
    else:
        df = pd.DataFrame(dataForTransfer)
    df['statisticsXGpa'] = df.apply(lambda row: row['Statistics'] * row['GPA'], axis=1)
    dfTransformer = sm.add_constant(df[['GPA', 'MIS', 'Statistics', 'statisticsXGpa']],has_constant='add')
    return dfTransformer

# %%
salaryRegModel4 = sm.OLS(
  sallaryMisDf["Salary"],
  salaryRegModel4Transformer(sallaryMisDf)
)

# %%
salaryRegModel4Fit = salaryRegModel4.fit()

# %%
print(salaryRegModel4Fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.796
# Method:                 Least Squares   F-statistic:                     116.9
# Date:                Fri, 11 Jul 2025   Prob (F-statistic):           1.44e-39
# Time:                        01:16:04   Log-Likelihood:                -298.78
# No. Observations:                 120   AIC:                             607.6
# Df Residuals:                     115   BIC:                             621.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             41.2856      2.267     18.215      0.000      36.796      45.775
# GPA                7.4828      0.701     10.674      0.000       6.094       8.871
# MIS                6.5400      0.588     11.118      0.000       5.375       7.705
# Statistics        14.5988      3.891      3.752      0.000       6.892      22.306
# statisticsXGpa    -2.3890      1.168     -2.045      0.043      -4.703      -0.075
# ==============================================================================
# Omnibus:                        0.348   Durbin-Watson:                   2.118
# Prob(Omnibus):                  0.840   Jarque-Bera (JB):                0.149
# Skew:                          -0.079   Prob(JB):                        0.928
# Kurtosis:                       3.068   Cond. No.                         59.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
salaryRegModel4Fit.transformer = salaryRegModel4Transformer
salaryRegModel4Fit.mainPredictor = partial(generalRegressionPredictor, salaryRegModel4Fit)
registerAJrjModel(
    salaryRegModel4Fit,
    {
        "modelName":f"silin_huang__salaryRegModel4Fit",
        "version":"1.0.1",
        "params": salaryRegModel4Fit.params.to_dict(),
        "score": float(salaryRegModel4Fit.rsquared),
        "modelLibraray": 'sm.OLS',
        "libraryMetadata": {
            "pvalues": salaryRegModel4Fit.pvalues.to_dict(),
            "r_squared": float(salaryRegModel4Fit.rsquared),
            "adj_r_squared": float(salaryRegModel4Fit.rsquared_adj)
        },
    
        "sampleData": {
            "dataForTransfer": salaryRegModel1SampleData
        }
    }
)
# Out:
# ✅ Uploaded encrypted ZIP to s3://273-g5/silin_huang__salaryRegModel4Fit__1.0.1.pkl.zip
# {'_id': '686ff55b345d1a0ee0583e19',
#  'modelName': 'silin_huang__salaryRegModel4Fit',
#  'version': '1.0.1',
#  'params': {'const': 41.28560173035843,
#   'GPA': 7.482789834390648,
#   'MIS': 6.5400277738611905,
#   'Statistics': 14.59881478166703,
#   'statisticsXGpa': -2.388952874805371},
#  'score': 0.8025731076983917,
#  'modelLibraray': 'sm.OLS',
#  'libraryMetadata': {'pvalues': {'const': 1.1066906219868896e-35,
#    'GPA': 6.696417260882323e-19,
#    'MIS': 6.060691170759604e-20,
#    'Statistics': 0.00027652830741481627,
#    'statisticsXGpa': 0.043120458231495365},
#   'r_squared': 0.8025731076983917,
#   'adj_r_squared': 0.7957060853574662},
#  'sampleData': {'dataForTransfer': {'GPA': [3.53],
#    'MIS': [1],
#    'Statistics': [0]}},
#  'modelType': 'model',
#  'keepLastOnly': False,
#  'modelSizeBytes': 24286,
#  'zippedModelSizeBytes': 9327,
#  's3Url': '273-g5/silin_huang__salaryRegModel4Fit__1.0.1.pkl.zip',
#  'createdAt': '2025-07-10T17:16:11.290Z',
#  'updatedAt': '2025-07-10T17:16:11.290Z'}

# %%
def salaryRegModel5Transformer(dataForTransfer = None):
    import pandas as pd
    import statsmodels.api as sm
    if isinstance(dataForTransfer, pd.DataFrame):
        df = dataForTransfer.copy()
    else:
        df = pd.DataFrame(dataForTransfer)
    df['misXStatistics'] = df.apply(lambda row: row['MIS'] * row['Statistics'], axis=1)
    df['misXGpa'] = df.apply(lambda row: row['MIS'] * row['GPA'], axis=1)
    df['statisticsXGpa'] = df.apply(lambda row: row['Statistics'] * row['GPA'], axis=1)
    df['misXStatisticsXGpa'] = df.apply(lambda row: row['MIS'] * row['Statistics'] * row['GPA'], axis=1)
    dfTransformer = sm.add_constant(df[['GPA', 'MIS', 'Statistics', 'misXStatistics', 'misXGpa', 'statisticsXGpa', 'misXStatisticsXGpa']],has_constant='add')
    return dfTransformer

# %%
salaryRegModel5 = sm.OLS(
  sallaryMisDf["Salary"],
  salaryRegModel5Transformer(sallaryMisDf)
)

# %%
salaryRegModel5Fit = salaryRegModel5.fit()

# %%
print(salaryRegModel5Fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     70.92
# Date:                Fri, 11 Jul 2025   Prob (F-statistic):           3.21e-38
# Time:                        01:16:16   Log-Likelihood:                -294.58
# No. Observations:                 120   AIC:                             605.2
# Df Residuals:                     112   BIC:                             627.5
# Df Model:                           7
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 41.1153      2.648     15.530      0.000      35.870      46.361
# GPA                    7.6467      0.821      9.312      0.000       6.020       9.274
# MIS                    7.1292      4.811      1.482      0.141      -2.404      16.662
# Statistics            14.7168      5.027      2.927      0.004       4.756      24.678
# misXStatistics        -1.7802      7.856     -0.227      0.821     -17.346      13.786
# misXGpa               -0.5650      1.494     -0.378      0.706      -3.525       2.395
# statisticsXGpa        -2.7609      1.493     -1.849      0.067      -5.720       0.198
# misXStatisticsXGpa     1.5554      2.373      0.655      0.514      -3.147       6.257
# ==============================================================================
# Omnibus:                        0.517   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.772   Jarque-Bera (JB):                0.243
# Skew:                           0.092   Prob(JB):                        0.886
# Kurtosis:                       3.121   Cond. No.                         143.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
salaryRegModel5Fit.transformer = salaryRegModel5Transformer
salaryRegModel5Fit.mainPredictor = partial(generalRegressionPredictor, salaryRegModel5Fit)
registerAJrjModel(
    salaryRegModel5Fit,
    {
        "modelName":f"silin_huang__salaryRegModel5Fit",
        "version":"1.0.1",
        "params": salaryRegModel5Fit.params.to_dict(),
        "score": float(salaryRegModel5Fit.rsquared),
        "modelLibraray": 'sm.OLS',
        "libraryMetadata": {
            "pvalues": salaryRegModel5Fit.pvalues.to_dict(),
            "r_squared": float(salaryRegModel5Fit.rsquared),
            "adj_r_squared": float(salaryRegModel5Fit.rsquared_adj)
        },
    
        "sampleData": {
            "dataForTransfer": salaryRegModel1SampleData
        }
    }
)
# Out:
# ✅ Uploaded encrypted ZIP to s3://273-g5/silin_huang__salaryRegModel5Fit__1.0.1.pkl.zip
# {'_id': '686ff567345d1a0ee0583e1a',
#  'modelName': 'silin_huang__salaryRegModel5Fit',
#  'version': '1.0.1',
#  'params': {'const': 41.11531955690886,
#   'GPA': 7.646668746853538,
#   'MIS': 7.129158768589029,
#   'Statistics': 14.716808798396357,
#   'misXStatistics': -1.7801623726561928,
#   'misXGpa': -0.5650157616957578,
#   'statisticsXGpa': -2.760898413157042,
#   'misXStatisticsXGpa': 1.555379319793591},
#  'score': 0.8159203002419962,
#  'modelLibraray': 'sm.OLS',
#  'libraryMetadata': {'pvalues': {'const': 1.0629114359813339e-29,
#    'GPA': 1.2812519781792795e-15,
#    'MIS': 0.14120253543376654,
#    'Statistics': 0.00414044326541773,
#    'misXStatistics': 0.8211490534511772,
#    'misXGpa': 0.7059440619959427,
#    'statisticsXGpa': 0.06710763372470231,
#    'misXStatisticsXGpa': 0.513547425840772},
#   'r_squared': 0.8159203002419962,
#   'adj_r_squared': 0.804415319007121},
#  'sampleData': {'dataForTransfer': {'GPA': [3.53],
#    'MIS': [1],
#    'Statistics': [0]}},
#  'modelType': 'model',
#  'keepLastOnly': False,
#  'modelSizeBytes': 34234,
#  'zippedModelSizeBytes': 10519,
#  's3Url': '273-g5/silin_huang__salaryRegModel5Fit__1.0.1.pkl.zip',
#  'createdAt': '2025-07-10T17:16:23.160Z',
#  'updatedAt': '2025-07-10T17:16:23.160Z'}

# %% [markdown]
# ## AFTER AREFULLY LOOKUP WE RELIZED  salaryRegModel2Fit SO LETS KEEP IT AS THE BEST

# %%
compareDf = pd.read_csv('./salaryRegModelsComparison.csv')

# %%
compareDf
# Out:
#                     Models salaryRegModel1Fit          salaryRegModel2Fit  \
# 0                 Comments             Linear  non linear with MIS * STAT
# 1                Intercept        44.0072 0.0                44.0993  0.0
# 2                      GPA         6.6227 0.0                    6.71 0.0
# 3                      MIS         6.6071 0.0                   5.325 0.0
# 4               Statistics           6.73 0.0                   5.535 0.0
# 5         MIS * Statistics                  x                 3.491 0.004
# 6                MIS * GPA                  x                           x
# 7         Statistics * GPA                  x                           x
# 8   MIS * Statistics * GPA                  x                           x
# 9                      NaN                NaN                         NaN
# 10                      R2              0.795                 0.81 - BEST
#
#            salaryRegModel3Fit          salaryRegModel4Fit   salaryRegModel5Fit
# 0   non linear with MIS * GPA  non linear with Stat * GPA  non linear with all
# 1                  44.165 0.0                  41.285 0.0           41.115 0.0
# 2                  6.5737 0.0                   7.482 0.0           7.6467 0.0
# 3              6.160  0.114 *                    6.54 0.0        7.1292 0.141*
# 4                   6.735 0.0                 14.5988 0.0        14.7168 0.004
# 5                           x                           x      -1.7802 0.821 *
# 6              0.1381 0.907 *                           x       -0.565 0.706 *
# 7                           x                -2.389 0.043        -2.76 0.067 *
# 8                           x                           x       1.555  0.514 *
# 9                         NaN                         NaN                  NaN
# 10                      0.795                       0.803                0.816

# %%
registerAJrjModel(
    salaryRegModel2Fit,
    {
        "modelName":f"silin_huang__salaryRegModelBEST",
        "version":"1.0.1",
        "params": salaryRegModel2Fit.params.to_dict(),
        "score": float(salaryRegModel2Fit.rsquared),
        "modelLibraray": 'sm.OLS',
        "libraryMetadata": {
            "pvalues": salaryRegModel2Fit.pvalues.to_dict(),
            "r_squared": float(salaryRegModel2Fit.rsquared),
            "adj_r_squared": float(salaryRegModel2Fit.rsquared_adj)
        },
    
        "sampleData": {
            "dataForTransfer": salaryRegModel1SampleData
        }
    }
)
# Out:
# ✅ Uploaded encrypted ZIP to s3://273-g5/silin_huang__salaryRegModelBEST__1.0.1.pkl.zip
# {'_id': '686ff572345d1a0ee0583e1b',
#  'modelName': 'silin_huang__salaryRegModelBEST',
#  'version': '1.0.1',
#  'params': {'const': 44.099326871515935,
#   'GPA': 6.710928968502127,
#   'MIS': 5.325020933077331,
#   'Statistics': 5.5349839504436105,
#   'misXStatistics': 3.4914565653155343},
#  'score': 0.8095004820146133,
#  'modelLibraray': 'sm.OLS',
#  'libraryMetadata': {'pvalues': {'const': 2.1308984053352826e-47,
#    'GPA': 2.206820882598635e-22,
#    'MIS': 3.2245297182829286e-11,
#    'Statistics': 2.259035391650431e-12,
#    'misXStatistics': 0.004233931884691076},
#   'r_squared': 0.8095004820146133,
#   'adj_r_squared': 0.8028744118238172},
#  'sampleData': {'dataForTransfer': {'GPA': [3.53],
#    'MIS': [1],
#    'Statistics': [0]}},
#  'modelType': 'model',
#  'keepLastOnly': False,
#  'modelSizeBytes': 24286,
#  'zippedModelSizeBytes': 9279,
#  's3Url': '273-g5/silin_huang__salaryRegModelBEST__1.0.1.pkl.zip',
#  'createdAt': '2025-07-10T17:16:34.722Z',
#  'updatedAt': '2025-07-10T17:16:34.722Z'}
